# %% [markdown]
# #**YOLOv8 is trained for Object Detection and Image Segmentation and Image Classification Tasks. We will run  Image Segementation tasks in this Tutorial**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Before Running The Script, Please Make Sure, You Have Selected the Run Time as GPU

# %% [markdown]
# #**Import the Required Library**

# %%
from IPython.display import Image

# %% [markdown]
# #**Install Ultralytics Library**

# %%
# !pip install ultralytics==8.0.0
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 219.8/219.8 kB 3.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 7.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 8.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 7.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 8.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 10.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 41.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 37.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 69.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 1.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 2.8 MB/s eta 0:00:00
# ...

# %% [markdown]
# #**Check Whether the GPU is Available or Not**

# %%
import torch

# %%
torch.cuda.is_available()
# Out:
# True

# %%
torch.__version__
# Out:
# '2.2.1+cu121'

# %% [markdown]
# #**Download the Demo Image and Video**

# %%
# !gdown "https://drive.google.com/uc?id=1q-sNrJfUi6PjvT8mFfEw1Cq4eCavdklK&confirm=t"
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/gdown", line 5, in <module>
#     from gdown.cli import main
#   File "/usr/local/lib/python3.10/dist-packages/gdown/__init__.py", line 4, in <module>
#     from .cached_download import cached_download
#   File "/usr/local/lib/python3.10/dist-packages/gdown/cached_download.py", line 3, in <module>
#     import hashlib
#   File "/usr/lib/python3.10/hashlib.py", line 170, in <module>
#     import _hashlib
# KeyboardInterrupt
# ^C

# %%
# !gdown "https://drive.google.com/uc?id=1hl_NNFciFwImmqplL3RkozpiIa8I38cd&confirm=t"
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1hl_NNFciFwImmqplL3RkozpiIa8I38cd&confirm=t
# To: /content/demo.mp4
# 100% 11.5M/11.5M [00:00<00:00, 136MB/s]

# %% [markdown]
# #**Image Segmentation**

# %%
# !yolo task=segment mode=predict model=yolov8s-seg.pt source='/content/1.jpg'
# Out:
# 2024-04-06 08:45:36.606983: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-06 08:45:36.607041: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-06 08:45:36.608489: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-06 08:45:37.870974: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.0 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Fusing layers...
# YOLOv8s-seg summary: 195 layers, 11810560 parameters, 0 gradients, 42.6 GFLOPs
# WARNING ⚠️ NMS time limit 0.550s exceeded
# ...

# %% [markdown]
# #**Dispay the Output Image**

# %%
Image('/content/runs/segment/predict4/1.jpg')

# %% [markdown]
# #**Hide Labels and Confidence Value**

# %%
# !yolo task=segment mode=predict model=yolov8s-seg.pt source='/content/1.jpg'  hide_labels=True hide_conf=True
# Out:
# 2024-04-06 08:36:00.351014: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-06 08:36:00.351075: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-06 08:36:00.352477: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-06 08:36:01.626758: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.0 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Fusing layers...
# YOLOv8s-seg summary: 195 layers, 11810560 parameters, 0 gradients, 42.6 GFLOPs
# ...

# %% [markdown]
# #**Display the Output Image**

# %%
Image('/content/runs/segment/predict2/image1.jpg')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/IPython/core/display.py in _data_and_metadata(self, always_both)
#    1299         try:
# -> 1300             b64_data = b2a_base64(self.data).decode('ascii')
#    1301         except TypeError:
#
# TypeError: a bytes-like object is required, not 'str'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/IPython/core/formatters.py in __call__(self, obj, include, exclude)
#     968
#     969             if method is not None:
# --> 970                 return method(include=include, exclude=exclude)
#     971             return None
#     972         else:
#
# ...

# %% [markdown]
# #**Run Segmentation on Video**

# %%
# !yolo task=segment mode=predict model=yolov8s-seg.pt source='/content/demo.mp4'
# Out:
# 2024-04-06 08:47:05.538610: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-06 08:47:05.538660: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-06 08:47:05.540049: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-06 08:47:06.792559: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.0 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Fusing layers...
# YOLOv8s-seg summary: 195 layers, 11810560 parameters, 0 gradients, 42.6 GFLOPs
# ...

# %% [markdown]
# #**Display the Output Video for Segmentation**

# %%
# !rm  "/content/result_compressed.mp4"
# Out:
# rm: cannot remove '/content/result_compressed.mp4': No such file or directory

# %%
from IPython.display import HTML
from base64 import b64encode
import os

# Input video path
save_path = '/content/runs/segment/predict5/demo.mp4'

# Compressed video path
compressed_path = "/content/result_compressed.mp4"

os.system(f"ffmpeg -i {save_path} -vcodec libx264 {compressed_path}")

# Show video
mp4 = open(compressed_path,'rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
HTML("""
<video width=400 controls>
      <source src="%s" type="video/mp4">
</video>
""" % data_url)

# %% [markdown]
# #**Export Model in ONNX Format**

# %% [markdown]
# #**Segmentation**

# %%
# !yolo task=segment mode=export model=yolov8s-seg.pt format=onnx

# %% [markdown]
# #**To Do All this in Python Instead of Command Line**

# %% [markdown]
# #**For Image**

# %%
from ultralytics import YOLO

# %%
#Initialize YOLO with the model name
model = YOLO("yolov8m-seg.pt")
#Predict Method Takes all the parameters of the Command Line Interface
model.predict(source='/content/image1.jpg',  save=True, conf=0.5,save_txt=True)

# %% [markdown]
# #**Display the Output Image**

# %%
Image('/content/runs/segment/predict4/image1.jpg')

# %% [markdown]
# #**For Video**

# %%
#Initialize YOLO with the model name
model = YOLO("yolov8m-seg.pt")
#Predict Method Takes all the parameters of the Command Line Interface
model.predict(source='/content/demo.mp4',  save=True, conf=0.5, save_txt = False)

# %% [markdown]
# #**Display the Output Video**

# %%
# !rm "/content/result_compressed.mp4"

# %%
from IPython.display import HTML
from base64 import b64encode
import os

# Input video path
save_path = '/content/runs/segment/predict5/demo.mp4'

# Compressed video path
compressed_path = "/content/result_compressed.mp4"

os.system(f"ffmpeg -i {save_path} -vcodec libx264 {compressed_path}")

# Show video
mp4 = open(compressed_path,'rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
HTML("""
<video width=400 controls>
      <source src="%s" type="video/mp4">
</video>
""" % data_url)

# %% [markdown]
# #**To Export the Model in the onnx Format comment model.predict line and add the model.export()**

# %%
#Initialize YOLO with the model name
model = YOLO("yolov8m-seg.pt")
#Export the Model in the onnx format
model.export(format="onnx")
